# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import sys
sys.path.append('../')

from config import *
import pandas as pd
from tools import *
import numpy as np
from sklearn.model_selection import KFold
import lightgbm as lgb
from tqdm import tqdm
from scipy import sparse
import matplotlib.pyplot as plt
import scipy

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
TARGET = 'gender'

# %%
### target
target = pd.read_pickle(TRAIN_DIR+USER_LOG_PATH)
target = target.groupby(['user_id']).agg('first').reset_index()

# %% [markdown]
# ## 点击list TFIDF

# %%
def get_tfidf(feat):
    tr_click_seq = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT[feat])
    ts_click_seq = pd.read_pickle(TEST_DIR+CLK_PATH_DICT[feat])

    click_seq = pd.concat([tr_click_seq, ts_click_seq], axis=0)[feat].values.tolist()

    tfidf = TfidfVectorizer(tokenizer=lambda x: x, max_features=100000, max_df=0.9, min_df=30, lowercase=False)
    tfidf_user = tfidf.fit_transform(click_seq)

    tfidf_user = tfidf_user.astype('float32')
    return tfidf_user

# %%
feature_columns = ['time', 'creative_id', 'ad_id', 'product_id', 'product_category', 'advertiser_id', 'industry']

# %%
tfidf_dict = dict()
for feat in feature_columns:
    tfidf_dict[feat] = get_tfidf(feat)

# %%
for feat in feature_columns:
    scipy.sparse.save_npz(TRAIN_DIR+'tfidf_%s.npz'%feat, tfidf_dict[feat])

# %% [markdown]
# ### Stacking Feature

# %%
temp1 = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT['ad_id'])
temp2 = pd.read_pickle(TEST_DIR+CLK_PATH_DICT['ad_id'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.calibration import CalibratedClassifierCV

# %%
N_SPLITS = 5
folds = KFold(n_splits=N_SPLITS, shuffle=True, random_state=2020)

# %%
train_df = temp1[['user_id']]
test_df = temp2[['user_id']]

# %%
STACKING_FEAT = ['lr', 'sgd', 'pac', 'rc', 'bnb', 'mnb']
STACKING_MODEL = [LogisticRegression(n_jobs=6), 
                  CalibratedClassifierCV(SGDClassifier(early_stopping=True, n_jobs=6)),
                  PassiveAggressiveClassifier(early_stopping=True, n_jobs=6), 
                  RidgeClassifier(),
                  BernoulliNB(), 
                  MultinomialNB()]
STACKING_MODEL = dict(zip(STACKING_FEAT, STACKING_MODEL))

# %%
def get_stacking_tfidf_feat(feat):
    tfidf_user = tfidf_dict[feat]

    train_csr = tfidf_user[:900000]
    test_csr  = tfidf_user[900000:]

    X_train, Y_train = train_csr, target[TARGET]-1
    X_test = test_csr

    for mode in STACKING_FEAT:
        if TARGET == 'age':
            for i in range(10):
                train_df[TARGET+'_'+mode+'_'+feat+'_'+str(i)] = 0.
                test_df[TARGET+'_'+mode+'_'+feat+'_'+str(i)] = 0.   
            predict_age = np.zeros((len(test_df), 10))
        else:
            train_df[TARGET+'_'+mode+'_'+feat] = 0.
            test_df[TARGET+'_'+mode+'_'+feat] = 0.                
            predict_age = np.zeros((len(test_df), ))

        for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train, Y_train)):
            print("Feature: {}, Model: {}, fold n°{}".format(feat, mode, fold_+1))
            x_train, y_train = X_train[trn_idx], Y_train[trn_idx]
            x_val, y_val = X_train[val_idx], Y_train[val_idx]

            model = STACKING_MODEL[mode]
            model.fit(x_train, y_train)

            r = model.score(x_val, y_val)
            print("accuracy:", r)

            if TARGET == 'age':
                try:
                    train_df.loc[val_idx, ['%s_%s_%s_%d'% (TARGET, mode, feat, i) for i in range(10)]] = model.predict_proba(x_val)
                    predict_age += model.predict_proba(X_test)
                except AttributeError:
                    train_df.loc[val_idx, ['%s_%s_%s_%d'% (TARGET, mode, feat, i) for i in range(10)]] = model.decision_function(x_val)
                    predict_age += model.decision_function(X_test)
            else:
                try:
                    train_df.loc[val_idx, ['%s_%s_%s'% (TARGET, mode, feat)]] = model.predict_proba(x_val)[:, 0]
                    predict_age += model.predict_proba(X_test)[:, 0]
                except AttributeError:
                    train_df.loc[val_idx, ['%s_%s_%s'% (TARGET, mode, feat)]] = model.decision_function(x_val)
                    predict_age += model.decision_function(X_test)

        if TARGET == 'age':
            test_df.loc[:, ['%s_%s_%s_%d'% (TARGET, mode, feat, i) for i in range(10)]] = predict_age/N_SPLITS
        else:
            test_df.loc[:, ['%s_%s_%s'% (TARGET, mode, feat)]] = predict_age/N_SPLITS

# %%
for feat in feature_columns:
    get_stacking_tfidf_feat(feat)
# Out:
# Feature: time, Model: lr, fold n°1
# accuracy: 0.6686222222222222
# Feature: time, Model: lr, fold n°2
# accuracy: 0.6710166666666667
# Feature: time, Model: lr, fold n°3
# accuracy: 0.6699944444444444
# Feature: time, Model: lr, fold n°4
# accuracy: 0.6692166666666667
# Feature: time, Model: lr, fold n°5
# accuracy: 0.6689833333333334
# Feature: time, Model: sgd, fold n°1
# accuracy: 0.6686222222222222
# Feature: time, Model: sgd, fold n°2
# accuracy: 0.6710166666666667
# Feature: time, Model: sgd, fold n°3
# accuracy: 0.6699944444444444
# Feature: time, Model: sgd, fold n°4
# accuracy: 0.6692166666666667
# Feature: time, Model: sgd, fold n°5
# accuracy: 0.6689833333333334
# Feature: time, Model: pac, fold n°1
# accuracy: 0.6161944444444445
# Feature: time, Model: pac, fold n°2
# accuracy: 0.6414333333333333
# Feature: time, Model: pac, fold n°3
# accuracy: 0.5895277777777778
# Feature: time, Model: pac, fold n°4
# accuracy: 0.5227166666666667
# Feature: time, Model: pac, fold n°5
# accuracy: 0.6196888888888888
# Feature: time, Model: rc, fold n°1
# accuracy: 0.6686222222222222
# Feature: time, Model: rc, fold n°2
# accuracy: 0.6710166666666667
# Feature: time, Model: rc, fold n°3
# accuracy: 0.6699944444444444
# Feature: time, Model: rc, fold n°4
# accuracy: 0.6692166666666667
# Feature: time, Model: rc, fold n°5
# accuracy: 0.6689833333333334
# Feature: time, Model: bnb, fold n°1
# accuracy: 0.6013277777777778
# Feature: time, Model: bnb, fold n°2
# accuracy: 0.5991333333333333
# Feature: time, Model: bnb, fold n°3
# accuracy: 0.5990833333333333
# Feature: time, Model: bnb, fold n°4
# accuracy: 0.6002833333333333
# Feature: time, Model: bnb, fold n°5
# accuracy: 0.5990666666666666
# Feature: time, Model: mnb, fold n°1
# accuracy: 0.6686222222222222
# Feature: time, Model: mnb, fold n°2
# accuracy: 0.6710166666666667
# Feature: time, Model: mnb, fold n°3
# accuracy: 0.6699944444444444
# Feature: time, Model: mnb, fold n°4
# accuracy: 0.6692166666666667
# Feature: time, Model: mnb, fold n°5
# accuracy: 0.6689833333333334
# Feature: creative_id, Model: lr, fold n°1
# accuracy: 0.9100388888888888
# Feature: creative_id, Model: lr, fold n°2
# accuracy: 0.9105
# Feature: creative_id, Model: lr, fold n°3
# accuracy: 0.9093
# Feature: creative_id, Model: lr, fold n°4
# accuracy: 0.9079277777777778
# Feature: creative_id, Model: lr, fold n°5
# accuracy: 0.9101611111111111
# Feature: creative_id, Model: sgd, fold n°1
# accuracy: 0.8772111111111112
# Feature: creative_id, Model: sgd, fold n°2
# accuracy: 0.8796722222222222
# Feature: creative_id, Model: sgd, fold n°3
# accuracy: 0.8789111111111111
# Feature: creative_id, Model: sgd, fold n°4
# accuracy: 0.8759944444444444
# Feature: creative_id, Model: sgd, fold n°5
# accuracy: 0.8769222222222223
# Feature: creative_id, Model: pac, fold n°1
# accuracy: 0.8879833333333333
# Feature: creative_id, Model: pac, fold n°2
# accuracy: 0.8895388888888889
# Feature: creative_id, Model: pac, fold n°3
# accuracy: 0.8879611111111111
# Feature: creative_id, Model: pac, fold n°4
# accuracy: 0.88705
# Feature: creative_id, Model: pac, fold n°5
# accuracy: 0.8885222222222222
# Feature: creative_id, Model: rc, fold n°1
# accuracy: 0.8953
# Feature: creative_id, Model: rc, fold n°2
# accuracy: 0.8951333333333333
# Feature: creative_id, Model: rc, fold n°3
# accuracy: 0.8949944444444444
# Feature: creative_id, Model: rc, fold n°4
# accuracy: 0.8934388888888889
# Feature: creative_id, Model: rc, fold n°5
# accuracy: 0.8952555555555556
# Feature: creative_id, Model: bnb, fold n°1
# accuracy: 0.9085222222222222
# Feature: creative_id, Model: bnb, fold n°2
# accuracy: 0.9072555555555556
# Feature: creative_id, Model: bnb, fold n°3
# accuracy: 0.9069777777777778
# Feature: creative_id, Model: bnb, fold n°4
# accuracy: 0.9061333333333333
# Feature: creative_id, Model: bnb, fold n°5
# accuracy: 0.9069611111111111
# Feature: creative_id, Model: mnb, fold n°1
# accuracy: 0.9092111111111111
# Feature: creative_id, Model: mnb, fold n°2
# accuracy: 0.9083777777777777
# Feature: creative_id, Model: mnb, fold n°3
# accuracy: 0.9078611111111111
# Feature: creative_id, Model: mnb, fold n°4
# accuracy: 0.9067055555555555
# Feature: creative_id, Model: mnb, fold n°5
# accuracy: 0.9084944444444445
# Feature: ad_id, Model: lr, fold n°1
# accuracy: 0.9114111111111111
# Feature: ad_id, Model: lr, fold n°2
# accuracy: 0.9118111111111111
# Feature: ad_id, Model: lr, fold n°3
# accuracy: 0.9093888888888889
# Feature: ad_id, Model: lr, fold n°4
# accuracy: 0.9091388888888889
# Feature: ad_id, Model: lr, fold n°5
# accuracy: 0.9097944444444445
# Feature: ad_id, Model: sgd, fold n°1
# accuracy: 0.87835
# Feature: ad_id, Model: sgd, fold n°2
# accuracy: 0.8804666666666666
# Feature: ad_id, Model: sgd, fold n°3
# accuracy: 0.8802888888888889
# Feature: ad_id, Model: sgd, fold n°4
# accuracy: 0.8769555555555556
# Feature: ad_id, Model: sgd, fold n°5
# accuracy: 0.8778166666666667
# Feature: ad_id, Model: pac, fold n°1
# accuracy: 0.8891333333333333
# Feature: ad_id, Model: pac, fold n°2
# accuracy: 0.8882888888888889
# Feature: ad_id, Model: pac, fold n°3
# accuracy: 0.8877666666666667
# Feature: ad_id, Model: pac, fold n°4
# accuracy: 0.8885777777777778
# Feature: ad_id, Model: pac, fold n°5
# accuracy: 0.8843277777777778
# Feature: ad_id, Model: rc, fold n°1
# accuracy: 0.8960888888888889
# Feature: ad_id, Model: rc, fold n°2
# accuracy: 0.8957888888888889
# Feature: ad_id, Model: rc, fold n°3
# accuracy: 0.8949833333333334
# Feature: ad_id, Model: rc, fold n°4
# accuracy: 0.89385
# Feature: ad_id, Model: rc, fold n°5
# accuracy: 0.89545
# Feature: ad_id, Model: bnb, fold n°1
# accuracy: 0.9087833333333334
# Feature: ad_id, Model: bnb, fold n°2
# accuracy: 0.9075444444444445
# Feature: ad_id, Model: bnb, fold n°3
# accuracy: 0.9071666666666667
# Feature: ad_id, Model: bnb, fold n°4
# accuracy: 0.9064888888888889
# Feature: ad_id, Model: bnb, fold n°5
# accuracy: 0.9071111111111111
# Feature: ad_id, Model: mnb, fold n°1
# accuracy: 0.9096
# Feature: ad_id, Model: mnb, fold n°2
# accuracy: 0.9089166666666667
# Feature: ad_id, Model: mnb, fold n°3
# accuracy: 0.9081833333333333
# Feature: ad_id, Model: mnb, fold n°4
# accuracy: 0.9070333333333334
# Feature: ad_id, Model: mnb, fold n°5
# accuracy: 0.9089833333333334
# Feature: product_id, Model: lr, fold n°1
# accuracy: 0.8512166666666666
# Feature: product_id, Model: lr, fold n°2
# accuracy: 0.8512611111111111
# Feature: product_id, Model: lr, fold n°3
# accuracy: 0.8493111111111111
# Feature: product_id, Model: lr, fold n°4
# accuracy: 0.8496222222222222
# Feature: product_id, Model: lr, fold n°5
# accuracy: 0.8500222222222222
# Feature: product_id, Model: sgd, fold n°1
# accuracy: 0.8289388888888889
# Feature: product_id, Model: sgd, fold n°2
# accuracy: 0.8290777777777778
# Feature: product_id, Model: sgd, fold n°3
# accuracy: 0.8263611111111111
# Feature: product_id, Model: sgd, fold n°4
# accuracy: 0.8258722222222222
# Feature: product_id, Model: sgd, fold n°5
# accuracy: 0.8271
# Feature: product_id, Model: pac, fold n°1
# accuracy: 0.81845
# Feature: product_id, Model: pac, fold n°2
# accuracy: 0.8218277777777778
# Feature: product_id, Model: pac, fold n°3
# accuracy: 0.7987777777777778
# Feature: product_id, Model: pac, fold n°4
# accuracy: 0.8189777777777778
# Feature: product_id, Model: pac, fold n°5
# accuracy: 0.8154333333333333
# Feature: product_id, Model: rc, fold n°1
# accuracy: 0.8360722222222222
# Feature: product_id, Model: rc, fold n°2
# accuracy: 0.8359777777777778
# Feature: product_id, Model: rc, fold n°3
# accuracy: 0.8339722222222222
# Feature: product_id, Model: rc, fold n°4
# accuracy: 0.8348222222222222
# Feature: product_id, Model: rc, fold n°5
# accuracy: 0.8349277777777778
# Feature: product_id, Model: bnb, fold n°1
# accuracy: 0.7932222222222223
# Feature: product_id, Model: bnb, fold n°2
# accuracy: 0.7915611111111112
# Feature: product_id, Model: bnb, fold n°3
# accuracy: 0.7921611111111111
# Feature: product_id, Model: bnb, fold n°4
# accuracy: 0.7925333333333333
# Feature: product_id, Model: bnb, fold n°5
# accuracy: 0.7920333333333334
# Feature: product_id, Model: mnb, fold n°1
# accuracy: 0.8410611111111111
# Feature: product_id, Model: mnb, fold n°2
# accuracy: 0.8400388888888889
# Feature: product_id, Model: mnb, fold n°3
# accuracy: 0.8391944444444445
# Feature: product_id, Model: mnb, fold n°4
# accuracy: 0.8386555555555556
# Feature: product_id, Model: mnb, fold n°5
# accuracy: 0.8403333333333334
# Feature: product_category, Model: lr, fold n°1
# accuracy: 0.6744277777777777
# Feature: product_category, Model: lr, fold n°2
# accuracy: 0.6762555555555556
# Feature: product_category, Model: lr, fold n°3
# accuracy: 0.6757944444444445
# Feature: product_category, Model: lr, fold n°4
# accuracy: 0.6752944444444444
# Feature: product_category, Model: lr, fold n°5
# accuracy: 0.6755277777777777
# Feature: product_category, Model: sgd, fold n°1
# accuracy: 0.6699333333333334
# Feature: product_category, Model: sgd, fold n°2
# accuracy: 0.6725
# Feature: product_category, Model: sgd, fold n°3
# accuracy: 0.6712833333333333
# Feature: product_category, Model: sgd, fold n°4
# accuracy: 0.6706888888888889
# Feature: product_category, Model: sgd, fold n°5
# accuracy: 0.6710277777777778
# Feature: product_category, Model: pac, fold n°1
# accuracy: 0.6503277777777777
# Feature: product_category, Model: pac, fold n°2
# accuracy: 0.6503166666666667
# Feature: product_category, Model: pac, fold n°3
# accuracy: 0.6517944444444445
# Feature: product_category, Model: pac, fold n°4
# accuracy: 0.6725888888888889
# Feature: product_category, Model: pac, fold n°5
# accuracy: 0.6622888888888889
# Feature: product_category, Model: rc, fold n°1
# accuracy: 0.6743222222222223
# Feature: product_category, Model: rc, fold n°2
# accuracy: 0.6761611111111111
# Feature: product_category, Model: rc, fold n°3
# accuracy: 0.67575
# Feature: product_category, Model: rc, fold n°4
# accuracy: 0.6751833333333334
# Feature: product_category, Model: rc, fold n°5
# accuracy: 0.6751666666666667
# Feature: product_category, Model: bnb, fold n°1
# accuracy: 0.6702111111111111
# Feature: product_category, Model: bnb, fold n°2
# accuracy: 0.67115
# Feature: product_category, Model: bnb, fold n°3
# accuracy: 0.6722166666666667
# Feature: product_category, Model: bnb, fold n°4
# accuracy: 0.6711388888888888
# Feature: product_category, Model: bnb, fold n°5
# accuracy: 0.66935
# Feature: product_category, Model: mnb, fold n°1
# accuracy: 0.6702388888888889
# Feature: product_category, Model: mnb, fold n°2
# accuracy: 0.6724944444444444
# Feature: product_category, Model: mnb, fold n°3
# accuracy: 0.6717055555555556
# Feature: product_category, Model: mnb, fold n°4
# accuracy: 0.6704166666666667
# Feature: product_category, Model: mnb, fold n°5
# accuracy: 0.6704722222222222
# Feature: advertiser_id, Model: lr, fold n°1
# accuracy: 0.8899166666666667
# Feature: advertiser_id, Model: lr, fold n°2
# accuracy: 0.8907666666666667
# Feature: advertiser_id, Model: lr, fold n°3
# accuracy: 0.8894888888888889
# Feature: advertiser_id, Model: lr, fold n°4
# accuracy: 0.88965
# Feature: advertiser_id, Model: lr, fold n°5
# accuracy: 0.8895944444444445
# Feature: advertiser_id, Model: sgd, fold n°1
# accuracy: 0.8644722222222222
# Feature: advertiser_id, Model: sgd, fold n°2
# accuracy: 0.8642277777777778
# Feature: advertiser_id, Model: sgd, fold n°3
# accuracy: 0.8639166666666667
# Feature: advertiser_id, Model: sgd, fold n°4
# accuracy: 0.8625166666666667
# Feature: advertiser_id, Model: sgd, fold n°5
# accuracy: 0.8644888888888889
# Feature: advertiser_id, Model: pac, fold n°1
# accuracy: 0.8662222222222222
# Feature: advertiser_id, Model: pac, fold n°2
# accuracy: 0.86365
# Feature: advertiser_id, Model: pac, fold n°3
# accuracy: 0.8675555555555555
# Feature: advertiser_id, Model: pac, fold n°4
# accuracy: 0.86835
# Feature: advertiser_id, Model: pac, fold n°5
# accuracy: 0.8673444444444445
# Feature: advertiser_id, Model: rc, fold n°1
# accuracy: 0.8745277777777778
# Feature: advertiser_id, Model: rc, fold n°2
# accuracy: 0.8757277777777778
# Feature: advertiser_id, Model: rc, fold n°3
# accuracy: 0.8747444444444444
# Feature: advertiser_id, Model: rc, fold n°4
# accuracy: 0.8745166666666667
# Feature: advertiser_id, Model: rc, fold n°5
# accuracy: 0.8751222222222222
# Feature: advertiser_id, Model: bnb, fold n°1
# accuracy: 0.8491666666666666
# Feature: advertiser_id, Model: bnb, fold n°2
# accuracy: 0.8476166666666667
# Feature: advertiser_id, Model: bnb, fold n°3
# accuracy: 0.8482666666666666
# Feature: advertiser_id, Model: bnb, fold n°4
# accuracy: 0.8480111111111112
# Feature: advertiser_id, Model: bnb, fold n°5
# accuracy: 0.8483555555555555
# Feature: advertiser_id, Model: mnb, fold n°1
# accuracy: 0.8812277777777778
# Feature: advertiser_id, Model: mnb, fold n°2
# accuracy: 0.88205
# Feature: advertiser_id, Model: mnb, fold n°3
# accuracy: 0.8809666666666667
# Feature: advertiser_id, Model: mnb, fold n°4
# accuracy: 0.8809222222222223
# Feature: advertiser_id, Model: mnb, fold n°5
# accuracy: 0.8817666666666667
# Feature: industry, Model: lr, fold n°1
# accuracy: 0.8196166666666667
# Feature: industry, Model: lr, fold n°2
# accuracy: 0.8188444444444445
# Feature: industry, Model: lr, fold n°3
# accuracy: 0.8181166666666667
# Feature: industry, Model: lr, fold n°4
# accuracy: 0.8190944444444445
# Feature: industry, Model: lr, fold n°5
# accuracy: 0.8193833333333334
# Feature: industry, Model: sgd, fold n°1
# accuracy: 0.8159222222222222
# Feature: industry, Model: sgd, fold n°2
# accuracy: 0.8141388888888889
# Feature: industry, Model: sgd, fold n°3
# accuracy: 0.8131222222222222
# Feature: industry, Model: sgd, fold n°4
# accuracy: 0.8145111111111111
# Feature: industry, Model: sgd, fold n°5
# accuracy: 0.8143111111111111
# Feature: industry, Model: pac, fold n°1
# accuracy: 0.7703888888888889
# Feature: industry, Model: pac, fold n°2
# accuracy: 0.7408222222222223
# Feature: industry, Model: pac, fold n°3
# accuracy: 0.7667055555555555
# Feature: industry, Model: pac, fold n°4
# accuracy: 0.7495222222222222
# Feature: industry, Model: pac, fold n°5
# accuracy: 0.7605055555555555
# Feature: industry, Model: rc, fold n°1
# accuracy: 0.8097111111111112
# Feature: industry, Model: rc, fold n°2
# accuracy: 0.8091388888888889
# Feature: industry, Model: rc, fold n°3
# accuracy: 0.8084222222222223
# Feature: industry, Model: rc, fold n°4
# accuracy: 0.80785
# Feature: industry, Model: rc, fold n°5
# accuracy: 0.8098
# Feature: industry, Model: bnb, fold n°1
# accuracy: 0.8034388888888889
# Feature: industry, Model: bnb, fold n°2
# accuracy: 0.8015444444444444
# Feature: industry, Model: bnb, fold n°3
# accuracy: 0.8010333333333334
# Feature: industry, Model: bnb, fold n°4
# accuracy: 0.80355
# Feature: industry, Model: bnb, fold n°5
# accuracy: 0.8029111111111111
# Feature: industry, Model: mnb, fold n°1
# accuracy: 0.7662944444444444
# Feature: industry, Model: mnb, fold n°2
# accuracy: 0.7682722222222222
# Feature: industry, Model: mnb, fold n°3
# accuracy: 0.7670277777777778
# Feature: industry, Model: mnb, fold n°4
# accuracy: 0.7663277777777778
# Feature: industry, Model: mnb, fold n°5
# accuracy: 0.7671722222222223

# %%
train_df
# Out:
#          gender_lr_time  gender_sgd_time  gender_pac_time  gender_rc_time  \
# user_id
# 1              0.648696         0.668930         0.944642       -0.297491
# 2              0.669548         0.664804         0.134110       -0.337093
# 3              0.669105         0.672787        -0.619038       -0.337123
# 4              0.653514         0.667255        -0.296040       -0.306282
# 5              0.654967         0.670437        -1.566085       -0.308868
# ...                 ...              ...              ...             ...
# 899996         0.680420         0.668328         0.318026       -0.360206
# 899997         0.668221         0.669131         0.134251       -0.335602
# 899998         0.628080         0.663903         0.236978       -0.256817
# 899999         0.698420         0.670689        -1.408075       -0.396776
# 900000         0.660742         0.671364         1.178091       -0.319823
#
#          gender_bnb_time  gender_mnb_time  gender_lr_creative_id  \
# user_id
# 1               0.462687         0.671713               0.835503
# 2               0.762594         0.668370               0.909430
# 3               0.677538         0.665693               0.020077
# 4               0.556943         0.672132               0.846787
# 5               0.714468         0.664008               0.984522
# ...                  ...              ...                    ...
# 899996          0.524115         0.675844               0.994958
# 899997          0.547137         0.671363               0.284075
# 899998          0.457240         0.664080               0.001383
# 899999          0.623190         0.676225               0.693170
# 900000          0.499605         0.670091               0.754781
#
#          gender_sgd_creative_id  gender_pac_creative_id  \
# user_id
# 1                      0.892835               -1.015039
# 2                      0.974811               -1.134497
# 3                      0.042654                2.920288
# 4                      0.776120               -1.517223
# 5                      0.916422               -4.161588
# ...                         ...                     ...
# 899996                 0.967098               -5.865822
# 899997                 0.127350                0.079271
# 899998                 0.000007                5.494359
# 899999                 0.309457               -1.924441
# 900000                 0.595754               -0.618364
#
#          gender_rc_creative_id  ...  gender_pac_advertiser_id  \
# user_id                         ...
# 1                    -0.688012  ...                  0.300353
# 2                    -0.843744  ...                 -2.030304
# 3                     1.209945  ...                  6.451700
# 4                    -0.313161  ...                 -2.943552
# 5                    -0.600071  ...                 -3.656198
# ...                        ...  ...                       ...
# 899996               -1.064993  ...                 -3.908812
# 899997                0.223498  ...                  0.059045
# 899998                1.677639  ...                  1.179481
# 899999               -0.435933  ...                 -3.170398
# 900000               -0.229414  ...                  1.208198
#
#          gender_rc_advertiser_id  gender_bnb_advertiser_id  \
# user_id
# 1                      -0.350326              1.262292e-01
# 2                      -0.598583              9.995696e-01
# 3                       1.565887              2.756222e-14
# 4                      -0.308591              9.708748e-01
# 5                      -0.748906              9.999999e-01
# ...                          ...                       ...
# 899996                 -0.989946              9.999829e-01
# 899997                  0.289862              2.591802e-03
# 899998                  0.288408              3.063951e-03
# 899999                 -0.585541              9.936428e-01
# 900000                  0.029929              3.056565e-02
#
#          gender_mnb_advertiser_id  gender_lr_industry  gender_sgd_industry  \
# user_id
# 1                        0.631968            0.283545             0.283109
# 2                        0.875381            0.962025             0.970992
# 3                        0.004059            0.156557             0.188042
# 4                        0.801061            0.626361             0.592239
# 5                        0.949030            0.878941             0.868572
# ...                           ...                 ...                  ...
# 899996                   0.986726            0.995254             0.992567
# 899997                   0.388146            0.795320             0.818283
# 899998                   0.247355            0.236660             0.209853
# 899999                   0.848625            0.727672             0.755108
# 900000                   0.422823            0.797193             0.769014
#
#          gender_pac_industry  gender_rc_industry  gender_bnb_industry  \
# user_id
# 1                   1.686654            0.270643             0.059902
# 2                  -2.838671           -0.836342             0.953354
# 3                   0.532648            0.297195             0.120992
# 4                   0.791519           -0.137615             0.778883
# 5                  -0.194567           -0.662066             0.904946
# ...                      ...                 ...                  ...
# 899996             -3.503454           -1.055025             0.972449
# 899997             -2.211360           -0.469287             0.425104
# 899998              0.741282            0.317723             0.245038
# 899999              1.121421           -0.406496             0.724844
# 900000             -2.158940           -0.384416             0.330223
#
#          gender_mnb_industry
# user_id
# 1                   0.495623
# 2                   0.792184
# 3                   0.463241
# 4                   0.622790
# 5                   0.731858
# ...                      ...
# 899996              0.933512
# 899997              0.707043
# 899998              0.508796
# 899999              0.646590
# 900000              0.652013
#
# [900000 rows x 42 columns]

# %%
test_df
# Out:
#          gender_lr_time  gender_sgd_time  gender_pac_time  gender_rc_time  \
# user_id
# 3000001        0.611988         0.665523        -0.278999       -0.227355
# 3000002        0.674952         0.670754        -0.676000       -0.348080
# 3000003        0.673212         0.669087        -0.109545       -0.345335
# 3000004        0.685008         0.669606        -0.314923       -0.369650
# 3000005        0.696163         0.672596        -1.130813       -0.391934
# ...                 ...              ...              ...             ...
# 3999996        0.667522         0.669935        -0.593991       -0.333733
# 3999997        0.678694         0.670770        -0.536313       -0.356681
# 3999998        0.682950         0.669900        -0.304855       -0.364970
# 3999999        0.739746         0.673128        -1.297512       -0.486179
# 4000000        0.722487         0.673088        -0.735582       -0.447623
#
#          gender_bnb_time  gender_mnb_time  gender_lr_creative_id  \
# user_id
# 3000001         0.401027         0.665306               0.961757
# 3000002         0.843889         0.662736               0.000504
# 3000003         0.687963         0.669517               0.787192
# 3000004         0.581657         0.677478               0.674343
# 3000005         0.721877         0.672531               0.925923
# ...                  ...              ...                    ...
# 3999996         0.774528         0.668007               0.981350
# 3999997         0.596061         0.673025               0.936227
# 3999998         0.614546         0.673231               0.991494
# 3999999         0.913488         0.680087               0.998463
# 4000000         0.889474         0.676341               0.988926
#
#          gender_sgd_creative_id  gender_pac_creative_id  \
# user_id
# 3000001                0.878129               -3.312299
# 3000002                0.000009                6.784782
# 3000003                0.878595               -1.934049
# 3000004                0.879992               -0.621173
# 3000005                0.901521               -2.510141
# ...                         ...                     ...
# 3999996                0.975382               -3.325256
# 3999997                0.943127               -2.986435
# 3999998                0.975029               -3.090100
# 3999999                0.975919               -7.270050
# 4000000                0.778743               -6.137914
#
#          gender_rc_creative_id  ...  gender_pac_advertiser_id  \
# user_id                         ...
# 3000001              -0.844437  ...                 -4.412609
# 3000002               2.270311  ...                  3.457347
# 3000003              -0.784078  ...                 -0.129640
# 3000004              -0.276192  ...                 -1.473468
# 3000005              -0.634478  ...                 -4.314632
# ...                        ...  ...                       ...
# 3999996              -0.650442  ...                 -3.485233
# 3999997              -0.685637  ...                 -0.571536
# 3999998              -0.571941  ...                 -4.558176
# 3999999              -1.183701  ...                 -5.963000
# 4000000              -0.948906  ...                -10.090018
#
#          gender_rc_advertiser_id  gender_bnb_advertiser_id  \
# user_id
# 3000001                -0.740402              9.999997e-01
# 3000002                 1.131524              7.087798e-11
# 3000003                -0.292728              5.231506e-01
# 3000004                -0.685793              9.650879e-01
# 3000005                -1.162091              9.999999e-01
# ...                          ...                       ...
# 3999996                -0.644348              1.000000e+00
# 3999997                -0.041303              9.957324e-01
# 3999998                -1.070603              9.995602e-01
# 3999999                -1.209639              1.000000e+00
# 4000000                -1.383072              1.000000e+00
#
#          gender_mnb_advertiser_id  gender_lr_industry  gender_sgd_industry  \
# user_id
# 3000001                  0.991810            0.937451             0.918459
# 3000002                  0.066742            0.174078             0.181643
# 3000003                  0.644594            0.618586             0.665233
# 3000004                  0.841881            0.728553             0.775987
# 3000005                  0.974483            0.436384             0.393639
# ...                           ...                 ...                  ...
# 3999996                  0.980872            0.674566             0.665364
# 3999997                  0.869504            0.778683             0.788739
# 3999998                  0.928692            0.918071             0.903062
# 3999999                  0.998060            0.991472             0.986795
# 4000000                  0.999744            0.913051             0.900688
#
#          gender_pac_industry  gender_rc_industry  gender_bnb_industry  \
# user_id
# 3000001            -1.553361           -0.477851             0.966735
# 3000002             1.077396            0.376419             0.004175
# 3000003            -0.238797           -0.254284             0.518327
# 3000004            -0.086203           -0.442695             0.723972
# 3000005             0.601582            0.068277             0.486531
# ...                      ...                 ...                  ...
# 3999996             0.120904           -0.227713             0.881799
# 3999997            -0.721161           -0.303063             0.860273
# 3999998            -1.829606           -0.650254             0.974984
# 3999999            -3.502149           -1.074314             0.999982
# 4000000            -0.963172           -0.655374             0.999413
#
#          gender_mnb_industry
# user_id
# 3000001             0.811494
# 3000002             0.426089
# 3000003             0.643566
# 3000004             0.708266
# 3000005             0.621512
# ...                      ...
# 3999996             0.668348
# 3999997             0.666850
# 3999998             0.808529
# 3999999             0.912866
# 4000000             0.807710
#
# [1000000 rows x 42 columns]

# %%
# train_df = train_df.set_index('user_id')
# test_df = test_df.set_index('user_id')

# %%
train_df.to_pickle(TRAIN_DIR+'tfidf_stack_%s.pkl'%TARGET)

# %%
test_df.to_pickle(TEST_DIR+'tfidf_stack_%s.pkl'%TARGET)

# %% [markdown]
# ## 统计特征

# %%
### Per Day Click Times
tr_per_day_clk_times = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT['per_day_click'])
ts_per_day_clk_times = pd.read_pickle(TEST_DIR+CLK_PATH_DICT['per_day_click'])

### Kfold Target Encode
tr_kfold_te = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT['kfold_te'])
ts_kfold_te = pd.read_pickle(TEST_DIR+CLK_PATH_DICT['kfold_te'])

### Sequence Statistic Feature
tr_seq_statistic = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT['seq_statistic'])
ts_seq_statistic = pd.read_pickle(TEST_DIR+CLK_PATH_DICT['seq_statistic'])

# %% [markdown]
# ### Countvec 特征

# %%
tr_click_seq = pd.read_pickle(TRAIN_DIR+CLK_PATH_DICT['ad_id'])
ts_click_seq = pd.read_pickle(TEST_DIR+CLK_PATH_DICT['ad_id'])

assert tr_click_seq['user_id'].values.tolist() == train_df.index.values.tolist()
assert ts_click_seq['user_id'].values.tolist() == test_df.index.values.tolist()

click_seq = pd.concat([tr_click_seq, ts_click_seq], axis=0)['ad_id'].values.tolist()

cntv = CountVectorizer(tokenizer=lambda x: x, max_df=0.9, min_df=30, lowercase=False)

cntv_user = cntv.fit_transform(click_seq)

cntv_user = cntv_user.astype('float32')

# %%
scipy.sparse.save_npz(TRAIN_DIR+'countvec.npz', cntv_user)

# %% [markdown]
# ### Merge

# %%
train_df = pd.concat([tr_per_day_clk_times, tr_kfold_te, tr_seq_statistic, train_df], axis=1)
test_df = pd.concat([ts_per_day_clk_times, ts_kfold_te, ts_seq_statistic, test_df], axis=1)

# %%
train_csr = sparse.csr_matrix(train_df.values)
test_csr = sparse.csr_matrix(test_df.values)

# %%
train_csr = sparse.hstack((train_csr, cntv_user[:900000])).tocsr()
test_csr  = sparse.hstack((test_csr , cntv_user[900000:])).tocsr()

# %%
X_train, y_train = train_csr, target['age']-1
X_test = test_csr

# %% [markdown]
# # Metric

# %%
def accuracy(y_true, y_pred):
    assert len(y_true) == len(y_pred), "length of y_true and y_pred not equal"
    total_example = len(y_true)
    right_cnt = 0
    for t, p in zip(y_true, y_pred):
        if t == p:
            right_cnt += 1
    return right_cnt / total_example

# %% [markdown]
# # Model

# %%
param = { 
    'boosting_type': 'gbdt',  
    'objective': 'multiclass',  
    'num_class': 10,  
    'metric': ['multi_error'],  
    'num_leaves': 2**9,  
    'min_data_in_leaf': 500,  
    'learning_rate': 0.1,  
    'feature_fraction': 0.8,  
    'bagging_fraction': 0.8,  
    'bagging_freq': 5,  
    'lambda_l1': 0.4,  
    'lambda_l2': 0.5,  
    'min_gain_to_split': 0.2,  
    'verbose': -1,
    'num_threads':6,
    'n_estimators': 1000
}

# %%
N_SPLITS = 5
folds = KFold(n_splits=N_SPLITS, shuffle=True, random_state=np.random.randint(2020))
# 五折交叉验证
for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train, y_train)):
    print("fold n°{}".format(fold_+1))
    trn_data = lgb.Dataset(X_train[trn_idx], y_train[trn_idx])
    val_data = lgb.Dataset(X_train[val_idx], y_train[val_idx])

    clf = lgb.train(param, 
                    trn_data, 
                    valid_sets = [trn_data, val_data], 
                    verbose_eval = 100, 
                    early_stopping_rounds = 200)
    
    y_val_pred = clf.predict(X_train[val_idx])
    y_val_pred = np.argmax(y_val_pred,axis=-1).tolist()
    acc = accuracy(y_train[val_idx].values.tolist(), y_val_pred)
    print("kfold: {:d}, accuracy: {:.4f}".format(fold_+1, acc))
    
    break
