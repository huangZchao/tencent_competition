# %%
import pandas as pd

# %%
loss_str = '''Loss after epoch 0: 6416747.0
Loss after epoch 1: 10370790.0
Loss after epoch 2: 13705094.0
Loss after epoch 3: 16799236.0
Loss after epoch 4: 19286240.0
Loss after epoch 5: 21642486.0
Loss after epoch 6: 23906436.0
Loss after epoch 7: 26070932.0
Loss after epoch 8: 28161300.0
Loss after epoch 9: 30190656.0
Loss after epoch 10: 32164218.0
Loss after epoch 11: 33890732.0
Loss after epoch 12: 35081412.0
Loss after epoch 13: 36259576.0
Loss after epoch 14: 37424928.0
Loss after epoch 15: 38568656.0
Loss after epoch 16: 39698108.0
Loss after epoch 17: 40819476.0
Loss after epoch 18: 41918392.0
Loss after epoch 19: 43004072.0
Loss after epoch 20: 44083020.0
Loss after epoch 21: 45144124.0
Loss after epoch 22: 46193696.0
Loss after epoch 23: 47239928.0
Loss after epoch 24: 48271592.0
Loss after epoch 25: 49298420.0
Loss after epoch 26: 50315292.0
Loss after epoch 27: 51319240.0
Loss after epoch 28: 52313420.0
Loss after epoch 29: 53307060.0
Loss after epoch 30: 54288252.0
Loss after epoch 31: 55265928.0
Loss after epoch 32: 56235012.0
Loss after epoch 33: 57197780.0
Loss after epoch 34: 58154928.0
Loss after epoch 35: 59101720.0
Loss after epoch 36: 60044448.0
Loss after epoch 37: 60984056.0
Loss after epoch 38: 61918752.0
Loss after epoch 39: 62849388.0
Loss after epoch 40: 63778104.0
Loss after epoch 41: 64696724.0
Loss after epoch 42: 65611120.0
Loss after epoch 43: 66516584.0'''

loss = []
for line in loss_str.split('\n'):
    loss.append(float(line.split(':')[-1].strip()))

loss_df = pd.DataFrame(loss, columns=['loss'])

loss_df['loss_diff'] = loss_df['loss'] - loss_df['loss'].shift(1)

loss_df['loss_diff'].plot(kind='line')

# %%
loss_df
# Out:
#           loss  loss_diff
# 0    6416747.0        NaN
# 1   10370790.0  3954043.0
# 2   13705094.0  3334304.0
# 3   16799236.0  3094142.0
# 4   19286240.0  2487004.0
# 5   21642486.0  2356246.0
# 6   23906436.0  2263950.0
# 7   26070932.0  2164496.0
# 8   28161300.0  2090368.0
# 9   30190656.0  2029356.0
# 10  32164218.0  1973562.0
# 11  33890732.0  1726514.0
# 12  35081412.0  1190680.0
# 13  36259576.0  1178164.0
# 14  37424928.0  1165352.0
# 15  38568656.0  1143728.0
# 16  39698108.0  1129452.0
# 17  40819476.0  1121368.0
# 18  41918392.0  1098916.0
# 19  43004072.0  1085680.0
# 20  44083020.0  1078948.0
# 21  45144124.0  1061104.0
# 22  46193696.0  1049572.0
# 23  47239928.0  1046232.0
# 24  48271592.0  1031664.0
# 25  49298420.0  1026828.0
# 26  50315292.0  1016872.0
# 27  51319240.0  1003948.0
# 28  52313420.0   994180.0
# 29  53307060.0   993640.0
# 30  54288252.0   981192.0
# 31  55265928.0   977676.0
# 32  56235012.0   969084.0
# 33  57197780.0   962768.0
# ...
